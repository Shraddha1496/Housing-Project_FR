# %% [markdown]
# # Housing Project

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
#  - We have to work simultaneously on trin.csv as well as test.csv

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  127         120       RL          NaN     4928   Pave   NaN      IR1
# 1  889          20       RL         95.0    15865   Pave   NaN      IR1
# 2  793          60       RL         92.0     9920   Pave   NaN      IR1
# 3  110          20       RL        105.0    11751   Pave   NaN      IR1
# 4  422          20       RL          NaN    16635   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2007        WD         Normal     128000
# 1     10   2007        WD         Normal     268000
# 2      6   2007        WD         Normal     269790
# 3      1   2010       COD         Normal     190000
# 4      6   2009        WD         Normal     215000
#
# [5 rows x 81 columns]

# %%
# check shape of data
df.shape
# Out:
# (1168, 81)

# %%
df1 = pd.read_csv('test.csv')

# %%
df1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL         86.0    14157   Pave   NaN      IR1
# 1  1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2   929          20       RL          NaN    11838   Pave   NaN      Reg
# 3  1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4  1227          60       RL         86.0    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         HLS    AllPub  ...           0        0    NaN   NaN         NaN
# 1         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 2         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 3         Bnk    AllPub  ...           0        0    NaN   NaN         NaN
# 4         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      7    2007        WD         Normal
# 1       0      8    2009       COD        Abnorml
# 2       0      6    2009        WD         Normal
# 3       0      7    2009        WD         Normal
# 4       0      1    2008        WD         Normal
#
# [5 rows x 80 columns]

# %%
df1.shape
# Out:
# (292, 80)

# %%
# check null values
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      214
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df1.isnull().sum()
# Out:
# Id                0
# MSSubClass        0
# MSZoning          0
# LotFrontage      45
# LotArea           0
#                  ..
# MiscVal           0
# MoSold            0
# YrSold            0
# SaleType          0
# SaleCondition     0
# Length: 80, dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False)
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1168 non-null   int64
#  1   MSSubClass     1168 non-null   int64
#  2   MSZoning       1168 non-null   object
#  3   LotFrontage    954 non-null    float64
#  4   LotArea        1168 non-null   int64
#  5   Street         1168 non-null   object
#  6   Alley          77 non-null     object
#  7   LotShape       1168 non-null   object
#  8   LandContour    1168 non-null   object
#  9   Utilities      1168 non-null   object
#  10  LotConfig      1168 non-null   object
#  11  LandSlope      1168 non-null   object
#  12  Neighborhood   1168 non-null   object
#  13  Condition1     1168 non-null   object
#  14  Condition2     1168 non-null   object
#  15  BldgType       1168 non-null   object
#  16  HouseStyle     1168 non-null   object
#  17  OverallQual    1168 non-null   int64
#  18  OverallCond    1168 non-null   int64
#  19  YearBuilt      1168 non-null   int64
#  20  YearRemodAdd   1168 non-null   int64
#  21  RoofStyle      1168 non-null   object
#  22  RoofMatl       1168 non-null   object
#  23  Exterior1st    1168 non-null   object
#  24  Exterior2nd    1168 non-null   object
#  25  MasVnrType     1161 non-null   object
#  26  MasVnrArea     1161 non-null   float64
#  27  ExterQual      1168 non-null   object
#  28  ExterCond      1168 non-null   object
#  29  Foundation     1168 non-null   object
#  30  BsmtQual       1138 non-null   object
#  31  BsmtCond       1138 non-null   object
#  32  BsmtExposure   1137 non-null   object
#  33  BsmtFinType1   1138 non-null   object
#  34  BsmtFinSF1     1168 non-null   int64
#  35  BsmtFinType2   1137 non-null   object
#  36  BsmtFinSF2     1168 non-null   int64
#  37  BsmtUnfSF      1168 non-null   int64
#  38  TotalBsmtSF    1168 non-null   int64
#  39  Heating        1168 non-null   object
#  40  HeatingQC      1168 non-null   object
#  41  CentralAir     1168 non-null   object
#  42  Electrical     1168 non-null   object
#  43  1stFlrSF       1168 non-null   int64
#  44  2ndFlrSF       1168 non-null   int64
#  45  LowQualFinSF   1168 non-null   int64
#  46  GrLivArea      1168 non-null   int64
#  47  BsmtFullBath   1168 non-null   int64
#  48  BsmtHalfBath   1168 non-null   int64
#  49  FullBath       1168 non-null   int64
#  50  HalfBath       1168 non-null   int64
#  51  BedroomAbvGr   1168 non-null   int64
#  52  KitchenAbvGr   1168 non-null   int64
#  53  KitchenQual    1168 non-null   object
#  54  TotRmsAbvGrd   1168 non-null   int64
#  55  Functional     1168 non-null   object
#  56  Fireplaces     1168 non-null   int64
#  57  FireplaceQu    617 non-null    object
#  58  GarageType     1104 non-null   object
#  59  GarageYrBlt    1104 non-null   float64
#  60  GarageFinish   1104 non-null   object
#  61  GarageCars     1168 non-null   int64
#  62  GarageArea     1168 non-null   int64
#  63  GarageQual     1104 non-null   object
#  64  GarageCond     1104 non-null   object
#  65  PavedDrive     1168 non-null   object
#  66  WoodDeckSF     1168 non-null   int64
#  67  OpenPorchSF    1168 non-null   int64
#  68  EnclosedPorch  1168 non-null   int64
#  69  3SsnPorch      1168 non-null   int64
#  70  ScreenPorch    1168 non-null   int64
#  71  PoolArea       1168 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          237 non-null    object
#  74  MiscFeature    44 non-null     object
#  75  MiscVal        1168 non-null   int64
#  76  MoSold         1168 non-null   int64
#  77  YrSold         1168 non-null   int64
#  78  SaleType       1168 non-null   object
#  79  SaleCondition  1168 non-null   object
#  80  SalePrice      1168 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 739.2+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             292 non-null    int64
#  1   MSSubClass     292 non-null    int64
#  2   MSZoning       292 non-null    object
#  3   LotFrontage    247 non-null    float64
#  4   LotArea        292 non-null    int64
#  5   Street         292 non-null    object
#  6   Alley          14 non-null     object
#  7   LotShape       292 non-null    object
#  8   LandContour    292 non-null    object
#  9   Utilities      292 non-null    object
#  10  LotConfig      292 non-null    object
#  11  LandSlope      292 non-null    object
#  12  Neighborhood   292 non-null    object
#  13  Condition1     292 non-null    object
#  14  Condition2     292 non-null    object
#  15  BldgType       292 non-null    object
#  16  HouseStyle     292 non-null    object
#  17  OverallQual    292 non-null    int64
#  18  OverallCond    292 non-null    int64
#  19  YearBuilt      292 non-null    int64
#  20  YearRemodAdd   292 non-null    int64
#  21  RoofStyle      292 non-null    object
#  22  RoofMatl       292 non-null    object
#  23  Exterior1st    292 non-null    object
#  24  Exterior2nd    292 non-null    object
#  25  MasVnrType     291 non-null    object
#  26  MasVnrArea     291 non-null    float64
#  27  ExterQual      292 non-null    object
#  28  ExterCond      292 non-null    object
#  29  Foundation     292 non-null    object
#  30  BsmtQual       285 non-null    object
#  31  BsmtCond       285 non-null    object
#  32  BsmtExposure   285 non-null    object
#  33  BsmtFinType1   285 non-null    object
#  34  BsmtFinSF1     292 non-null    int64
#  35  BsmtFinType2   285 non-null    object
#  36  BsmtFinSF2     292 non-null    int64
#  37  BsmtUnfSF      292 non-null    int64
#  38  TotalBsmtSF    292 non-null    int64
#  39  Heating        292 non-null    object
#  40  HeatingQC      292 non-null    object
#  41  CentralAir     292 non-null    object
#  42  Electrical     291 non-null    object
#  43  1stFlrSF       292 non-null    int64
#  44  2ndFlrSF       292 non-null    int64
#  45  LowQualFinSF   292 non-null    int64
#  46  GrLivArea      292 non-null    int64
#  47  BsmtFullBath   292 non-null    int64
#  48  BsmtHalfBath   292 non-null    int64
#  49  FullBath       292 non-null    int64
#  50  HalfBath       292 non-null    int64
#  51  BedroomAbvGr   292 non-null    int64
#  52  KitchenAbvGr   292 non-null    int64
#  53  KitchenQual    292 non-null    object
#  54  TotRmsAbvGrd   292 non-null    int64
#  55  Functional     292 non-null    object
#  56  Fireplaces     292 non-null    int64
#  57  FireplaceQu    153 non-null    object
#  58  GarageType     275 non-null    object
#  59  GarageYrBlt    275 non-null    float64
#  60  GarageFinish   275 non-null    object
#  61  GarageCars     292 non-null    int64
#  62  GarageArea     292 non-null    int64
#  63  GarageQual     275 non-null    object
#  64  GarageCond     275 non-null    object
#  65  PavedDrive     292 non-null    object
#  66  WoodDeckSF     292 non-null    int64
#  67  OpenPorchSF    292 non-null    int64
#  68  EnclosedPorch  292 non-null    int64
#  69  3SsnPorch      292 non-null    int64
#  70  ScreenPorch    292 non-null    int64
#  71  PoolArea       292 non-null    int64
#  72  PoolQC         0 non-null      float64
#  73  Fence          44 non-null     object
#  74  MiscFeature    10 non-null     object
#  75  MiscVal        292 non-null    int64
#  76  MoSold         292 non-null    int64
#  77  YrSold         292 non-null    int64
#  78  SaleType       292 non-null    object
#  79  SaleCondition  292 non-null    object
# dtypes: float64(4), int64(34), object(42)
# memory usage: 182.6+ KB

# %%
# fill missing values by mean coz of floating values
df['LotFrontage'] = df['LotFrontage'].fillna(df['LotFrontage'].mean())

# %%
df.drop(['Alley'],axis=1,inplace=True)

# %%
# fill missing value of "LotFrontage" in test data
df1['LotFrontage'] = df1['LotFrontage'].fillna(df['LotFrontage'].mean())

# %%
df.drop(['PoolQC','Fence','MiscFeature'],axis=1,inplace=True)

# %%
df1.drop(['PoolQC','Fence','MiscFeature'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (1168, 77)

# %%
df1.shape
# Out:
# (292, 77)

# %%
df.drop(['Id'],axis=1,inplace=True)

# %%
df1.drop(['Id'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 76, dtype: int64

# %%
df1.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# Length: 76, dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False)
# Out:
# <AxesSubplot:>

# %%
df['BsmtCond'] = df['BsmtCond'].fillna(df['BsmtCond'].mode()[0])
df['BsmtQual'] = df['BsmtQual'].fillna(df['BsmtQual'].mode()[0])

# %%
df1['BsmtCond'] = df1['BsmtCond'].fillna(df1['BsmtCond'].mode()[0])
df1['BsmtQual'] = df1['BsmtQual'].fillna(df1['BsmtQual'].mode()[0])

# %%
df['FireplaceQu'] = df['FireplaceQu'].fillna(df['FireplaceQu'].mode()[0])
df['GarageType'] = df['GarageType'].fillna(df['GarageType'].mode()[0])

# %%
df.drop(['GarageYrBlt'],axis=1,inplace=True)

# %%
df['GarageFinish'] = df['GarageFinish'].fillna(df['GarageFinish'].mode()[0])
df['GarageQual'] = df['GarageQual'].fillna(df['GarageQual'].mode()[0])
df['GarageCond'] = df['GarageCond'].fillna(df['GarageCond'].mode()[0])

# %%
df.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 75, dtype: int64

# %%
df1.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# Length: 76, dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
df['BsmtExposure'] = df['BsmtExposure'].fillna(df['BsmtExposure'].mode(0))

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
df['BsmtFinType2'] = df['BsmtFinType2'].fillna(df['BsmtFinType2'].mode(0))

# %%
df['BsmtFinType1'] = df['BsmtFinType1'].fillna(df['BsmtFinType1'].mode(0))

# %%
df.shape
# Out:
# (1168, 75)

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0         120       RL     70.98847     4928   Pave      IR1         Lvl
# 1          20       RL     95.00000    15865   Pave      IR1         Lvl
# 2          60       RL     92.00000     9920   Pave      IR1         Lvl
# 3          20       RL    105.00000    11751   Pave      IR1         Lvl
# 4          20       RL     70.98847    16635   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 0    AllPub    Inside       Gtl  ...             0         0           0
# 1    AllPub    Inside       Mod  ...             0         0         224
# 2    AllPub   CulDSac       Gtl  ...             0         0           0
# 3    AllPub    Inside       Gtl  ...             0         0           0
# 4    AllPub       FR2       Gtl  ...             0         0           0
#
#   PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 0        0       0       2    2007        WD         Normal    128000
# 1        0       0      10    2007        WD         Normal    268000
# 2        0       0       6    2007        WD         Normal    269790
# 3        0       0       1    2010       COD         Normal    190000
# 4        0       0       6    2009        WD         Normal    215000
#
# [5 rows x 75 columns]

# %%
df['FireplaceQu'] = df['FireplaceQu'].fillna(df['FireplaceQu'].mode(0))

# %%
df['GarageQual'] = df['GarageQual'].fillna(df['GarageQual'].mode(0))

# %%
df['GarageCond'] = df['GarageCond'].fillna(df['GarageCond'].mode(0))

# %%
df.shape
# Out:
# (1168, 75)

# %%
df1['MasVnrType'] = df['MasVnrType'].fillna(df['MasVnrType'].mode(0))

# %%
df1['BsmtExposure'] = df1['BsmtExposure'].fillna(df1['BsmtExposure'].mode(0))

# %%
df1['FireplaceQu'] = df1['FireplaceQu'].fillna(df1['FireplaceQu'].mode(0))

# %%
df1['GarageType'] = df1['GarageType'].fillna(df1['GarageType'].mode()[0])

# %%
df1.drop(['GarageYrBlt'],axis=1,inplace=True)

# %%
df1['GarageQual'] = df1['GarageQual'].fillna(df1['GarageQual'].mode()[0])
df1['GarageCond'] = df1['GarageCond'].fillna(df1['GarageCond'].mode()[0])

# %%
df1['GarageFinish'] = df1['GarageFinish'].fillna(df1['GarageFinish'].mode()[0])

# %%
df1.shape
# Out:
# (292, 75)

# %%
## Handle categorical features

# %%
df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
#        'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
columns = ['MSZoning','Street',
       'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
       'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle',
       'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
       'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
       'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
       'Heating', 'HeatingQC',
       'CentralAir', 'Electrical', 'KitchenQual',
       'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish',
       'GarageQual', 'GarageCond', 'PavedDrive',
       'SaleType',
       'SaleCondition']

# %%
len(columns)
# Out:
# 39

# %%
df1.to_csv('formulatedtest.csv',index=False)

# %%
def category_onehot_multcols(multcolumns):
    df_final=final_df
    i=0
    for fields in multcolumns:
        
        print(fields)
        df_1 = pd.get_dummies(final_df[fields],drop_first=True)
        
        final_df.drop([fields],axis=1,inplace=True)
        if i==0:
            df_final=df_1.copy()
        else:
            df_final=pd.concat([final_df,df_1],axis=1)
        i=i+1
        
    df_final = pd.concat([final_df,df_final],axis=1)
    
    return df_final

# %%
main_df = df.copy()

# %%
## combine test data

df1 = pd.read_csv('formulatedtest.csv')

# %%
df1.shape
# Out:
# (292, 75)

# %%
df1.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          20       RL     86.00000    14157   Pave   NaN      IR1
# 1         120       RL     70.98847     5814   Pave   NaN      IR1
# 2          20       RL     70.98847    11838   Pave   NaN      Reg
# 3          70       RL     75.00000    12000   Pave   NaN      Reg
# 4          60       RL     86.00000    14598   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# 0         HLS    AllPub    Corner  ...          51             0         0
# 1         Lvl    AllPub   CulDSac  ...           0             0         0
# 2         Lvl    AllPub    Inside  ...         151             0         0
# 3         Bnk    AllPub    Inside  ...           0             0         0
# 4         Lvl    AllPub   CulDSac  ...          18             0         0
#
#   ScreenPorch PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0           0        0       0       7    2007        WD         Normal
# 1           0        0       0       8    2009       COD        Abnorml
# 2           0        0       0       6    2009        WD         Normal
# 3           0        0       0       7    2009        WD         Normal
# 4           0        0       0       1    2008        WD         Normal
#
# [5 rows x 75 columns]

# %%
# combine train and test data row wise
final_df = pd.concat([df,df1],axis=0)

# %%
final_df.shape
# Out:
# (1460, 76)

# %%
final_df = category_onehot_multcols(columns)
# Out:
# MSZoning
# Street
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition1
# Condition2
# BldgType
# HouseStyle
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# ExterQual
# ExterCond
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# Heating
# HeatingQC
# CentralAir
# Electrical
# KitchenQual
# Functional
# FireplaceQu
# GarageType
# GarageFinish
# GarageQual
# GarageCond
# PavedDrive
# SaleType
# SaleCondition

# %%
final_df.shape
# Out:
# (1460, 79)

# %%
final_df = final_df.loc[:,~final_df.columns.duplicated()]

# %%
final_df.shape
# Out:
# (1460, 42)

# %%
final_df.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0         120     70.98847     4928            6            5       1976
# 1          20     95.00000    15865            8            6       1970
# 2          60     92.00000     9920            7            5       1996
# 3          20    105.00000    11751            6            6       1977
# 4          20     70.98847    16635            6            7       1977
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  MiscVal  MoSold  \
# 0          1976         0.0         120           0  ...        0       2
# 1          1970         0.0         351         823  ...        0      10
# 2          1997         0.0         862           0  ...        0       6
# 3          1977       480.0         705           0  ...        0       1
# 4          2000       126.0        1246           0  ...        0       6
#
#    YrSold  SalePrice  Alley  AdjLand  Alloca  Family  Normal  Partial
# 0    2007   128000.0    NaN        0       0       0       1        0
# 1    2007   268000.0    NaN        0       0       0       1        0
# 2    2007   269790.0    NaN        0       0       0       1        0
# 3    2010   190000.0    NaN        0       0       0       1        0
# 4    2009   215000.0    NaN        0       0       0       1        0
#
# [5 rows x 42 columns]

# %%
df_train = final_df.iloc[:1168,:]
df_test = final_df.iloc[1168:,:]

# %%
df_test.drop(['SalePrice'],axis=1,inplace=True)
# Out:
# /Users/shraddhawaghmare/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_test.drop(['Alley'],axis=1,inplace=True)

# %%
df_test.shape
# Out:
# (292, 40)

# %%
x_train = df_train.drop(['SalePrice'],axis=1)
y_train = df_train['SalePrice']

# %%
df_train.drop(['Alley'],axis=1,inplace=True)

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in ./opt/anaconda3/lib/python3.9/site-packages (1.6.1)
# Requirement already satisfied: numpy in ./opt/anaconda3/lib/python3.9/site-packages (from xgboost) (1.20.3)
# Requirement already satisfied: scipy in ./opt/anaconda3/lib/python3.9/site-packages (from xgboost) (1.7.1)

# %%
import xgboost 
classifier = xgboost.XGBRegressor()
classifier.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
# save the model
import pickle
filename = 'finalized_model.pkl'
pickle.dump(classifier,open(filename,'wb'))

# %%
y_pred = classifier.predict(df_test)

# %%
y_pred
# Out:
# array([357904.44 , 218563.81 , 245126.58 , 183926.44 , 199452.81 ,
#         81992.37 , 130728.805, 381722.62 , 228665.95 , 159275.23 ,
#         74987.555, 153214.52 , 115471.78 , 153247.2  , 293040.62 ,
#        125615.17 , 112481.125, 126190.68 , 169403.33 , 152507.86 ,
#        170166.14 , 133997.77 , 152426.08 ,  72248.43 ,  94383.65 ,
#        119242.13 , 176330.16 , 161285.4  , 173310.27 ,  95971.07 ,
#        166858.4  , 177930.9  , 215287.66 , 156439.83 , 100606.805,
#        159526.47 , 192826.   , 115316.56 , 159533.5  , 145581.78 ,
#         94057.766, 338574.3  , 192492.7  , 176996.23 , 133452.47 ,
#        125247.94 , 115087.57 , 104455.14 , 210440.38 , 343232.94 ,
#        143544.42 , 182823.17 , 104008.7  , 102621.805, 290099.62 ,
#        129030.4  , 141669.62 , 187423.73 , 112545.27 , 250150.34 ,
#         91457.375, 167321.86 , 125308.77 , 145262.4  , 200918.81 ,
#         82608.69 , 153189.36 , 215431.38 , 142758.64 , 179854.39 ,
#        311446.   , 172004.75 , 189292.98 , 166640.05 , 140000.34 ,
#        230718.3  , 307591.3  , 195241.64 , 304169.38 , 137859.45 ,
#        203752.48 , 140075.81 , 138331.22 , 145384.34 , 185233.67 ,
#        190344.62 , 111553.27 , 419692.72 , 172455.56 , 175042.4  ,
#        267650.06 , 114607.83 , 130534.76 , 107334.69 , 169491.67 ,
#        156652.83 , 236311.23 , 158470.28 , 391999.97 , 125602.99 ,
#        240610.34 ,  80864.43 ,  98587.59 , 142590.73 , 198350.67 ,
#        152002.   , 285505.56 , 123538.75 , 185097.33 , 197891.28 ,
#        189306.2  , 169932.   , 233000.42 , 204181.22 , 123674.29 ,
#         80798.055, 140621.27 , 194167.5  , 141801.89 , 110366.15 ,
#         89504.09 , 199487.3  , 316794.44 , 128503.03 , 147044.34 ,
#        198421.06 , 122987.64 , 158769.98 ,  82202.16 , 117355.1  ,
#        148886.23 , 242231.08 , 147290.27 , 136267.84 , 190351.64 ,
#        278412.28 , 207976.16 ,  96418.58 , 280921.88 , 122054.14 ,
#        121322.164, 393653.5  ,  88018.53 , 403869.78 , 173622.12 ,
#        256622.47 , 153232.48 , 103185.01 , 104696.625, 192487.52 ,
#        162174.55 , 140863.36 , 182433.98 , 117300.82 , 106969.35 ,
#        180849.95 , 190218.27 , 226217.39 , 121864.336, 173210.31 ,
#        199205.95 , 140593.17 , 202286.95 , 110548.42 ,  93232.586,
#        239122.98 , 186060.56 , 181069.33 , 132283.19 , 225823.48 ,
#        160664.64 , 127762.51 , 123991.82 , 265882.72 , 142681.69 ,
#        383891.   , 132613.28 , 114044.56 , 135545.7  , 141544.67 ,
#        205002.7  , 156844.48 , 273533.75 , 163504.5  , 506393.06 ,
#        346155.4  , 229510.66 ,  96932.055, 158367.84 , 151074.84 ,
#        116399.02 , 220796.53 , 179486.27 ,  83334.93 , 121508.445,
#         57676.19 , 172246.12 , 192518.64 , 128127.586, 151969.89 ,
#        142606.56 ,  84773.89 , 271451.72 , 304030.78 , 127476.695,
#        120822.49 , 234463.48 , 153866.6  , 125292.914, 128775.37 ,
#         87197.195, 163260.58 , 176623.03 , 200098.77 ,  81754.11 ,
#        240747.6  , 149168.27 , 125262.39 , 106073.055, 185099.14 ,
#        209658.25 , 205226.27 , 262449.06 , 116817.164, 184777.4  ,
#        357365.94 , 183838.88 ,  88129.5  , 327717.12 , 189493.44 ,
#         87407.79 , 139990.97 ,  86362.   , 135162.78 , 116309.75 ,
#        223404.19 , 170652.47 , 165036.1  , 216684.47 , 180014.52 ,
#        218334.9  , 145907.28 , 409043.28 , 110611.734, 144898.83 ,
#        255913.72 , 203762.42 , 260906.66 , 133080.03 , 154951.11 ,
#        191540.02 , 213667.62 , 158651.38 ,  96796.06 ,  89183.27 ,
#        197289.03 , 135096.8  , 365571.3  , 165884.61 , 109985.59 ,
#        149706.03 , 198315.72 ,  99481.586, 140376.92 , 194084.12 ,
#        171805.55 , 111514.125, 178174.06 , 262138.88 , 225435.33 ,
#        146854.14 , 134529.53 , 338070.1  , 262638.84 , 278930.56 ,
#        204348.5  , 173632.78 , 104606.805, 192611.86 , 366332.53 ,
#        122842.03 , 330437.03 , 160597.17 , 310110.47 , 140179.11 ,
#        123114.67 , 162616.45 , 251123.75 , 144586.27 , 144817.5  ,
#        147649.08 ,  95238.484], dtype=float32)

# %%
import xgboost
regressor = xgboost.XGBRegressor()

# %%
booster = ['gbtree','gblinear']
base_score = [0.25,0.5,0.75,1]

# %%
## Hyperparameter Optimization

n_estimators = [100,500,900,1100,1500]
max_depth = [2,3,5,10,15]
booster = ['gbtree','gblinear']
learning_rate = [0.05,0.1,0.15,0.20]
min_child_weight = [1,2,3,4]

# define the grid of parameters to search
hyperparameter_grid = {
    'n_estimators': n_estimators,
    'max_depth' : max_depth,
    'booster' : booster,
    'learning_rate' : learning_rate,
    'min_child_weight' : min_child_weight,
    'base_score' : base_score
}

# %%
# set up the random search with 4-fold cross validation
from sklearn.model_selection import RandomizedSearchCV
random_cv = RandomizedSearchCV(estimator=regressor,
                              param_distributions = hyperparameter_grid,
                              cv=5,n_iter=50,
                              scoring='neg_mean_absolute_error',n_jobs=4,
                              verbose = 5,
                              return_train_score = True,
                              random_state = 42)

# %%
random_cv.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, gamma=None,
#                                           gpu_id=None, grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=None, max_bin=None,
#                                           m...
#                                           reg_alpha=None, reg_lambda=None, ...),
#                    n_iter=50, n_jobs=4,
#                    param_distributions={'base_score': [0.25, 0.5, 0.75, 1],
#                                         'booster': ['gbtree', 'gblinear'],
#                                         'learning_rate': [0.05, 0.1, 0.15, 0.2],
#                                         'max_depth': [2, 3, 5, 10, 15],
#                                         'min_child_weight': [1, 2, 3, 4],
#                                         'n_estimators': [100, 500, 900, 1100,
#                                                          1500]},
#                    random_state=42, return_train_score=True,
#                    scoring='neg_mean_absolute_error', verbose=5)

# %%
random_cv.best_estimator_
# Out:
# XGBRegressor(base_score=0.25, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.1, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=2, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=900, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
regressor = xgboost.XGBRegressor(base_score=0.25, booster='gbtree', callbacks=None,
             colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
             early_stopping_rounds=None, enable_categorical=False,
             eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
             importance_type=None, interaction_constraints='',
             learning_rate=0.1, max_bin=256, max_cat_to_onehot=4,
             max_delta_step=0, max_depth=2, max_leaves=0, min_child_weight=1,
             monotone_constraints='()', n_estimators=900, n_jobs=0,
             num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
             reg_lambda=1)

# %%
regressor.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.25, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.1, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=2, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=900, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
# save the model
import pickle
filename = 'finalized_model.pkl'
pickle.dump(classifier,open(filename,'wb'))

# %%
y_pred = regressor.predict(df_test)

# %%
y_pred
# Out:
# array([375815.72 , 205024.58 , 255712.17 , 181135.42 , 207560.53 ,
#         83104.914, 122484.04 , 325091.   , 216147.08 , 166270.08 ,
#         72805.77 , 133101.11 , 127508.016, 235623.36 , 273943.34 ,
#        112015.7  , 114434.93 , 119973.164, 167214.8  , 178640.95 ,
#        156024.95 , 137387.39 , 138412.67 ,  69115.61 ,  91446.63 ,
#        126967.81 , 174757.62 , 137438.8  , 162967.2  ,  92344.17 ,
#        137928.53 , 184098.61 , 204102.31 , 175664.39 , 109040.25 ,
#        171753.28 , 185320.23 , 110255.82 , 154523.28 , 148175.72 ,
#         83524.57 , 327755.53 , 195014.6  , 186160.81 , 142952.58 ,
#        130227.54 , 120333.55 ,  89791.68 , 207150.98 , 337021.6  ,
#        138397.03 , 182972.62 ,  90888.43 ,  92108.53 , 289964.03 ,
#        127607.21 , 145416.98 , 186322.34 , 117139.96 , 243411.86 ,
#         89212.75 , 178343.45 , 127094.18 , 138505.64 , 204737.97 ,
#         83022.76 , 156543.75 , 196582.55 , 138467.61 , 174765.97 ,
#        352707.97 , 156929.44 , 191316.48 , 150223.92 , 136630.25 ,
#        243096.31 , 301937.44 , 206144.77 , 294580.16 , 133632.55 ,
#        197344.56 , 140434.88 , 148026.27 , 155612.62 , 172248.06 ,
#        232886.83 , 105493.52 , 392675.28 , 154402.81 , 171297.23 ,
#        271449.28 , 139669.61 , 127865.85 , 133734.34 , 190497.5  ,
#        165057.58 , 230287.56 , 159417.44 , 389557.34 , 120745.03 ,
#        261885.38 ,  75948.266, 115159.25 , 135866.36 , 197665.22 ,
#        146461.6  , 280357.2  , 137187.36 , 179959.14 , 197587.56 ,
#        197725.7  , 157208.95 , 220551.33 , 248995.7  , 126946.43 ,
#         76362.06 , 132333.83 , 186941.11 , 149152.08 ,  96266.25 ,
#        105444.99 , 196388.36 , 268874.25 , 126503.14 , 146552.89 ,
#        186171.47 , 120468.27 , 178554.12 ,  75483.27 ,  97609.99 ,
#        147116.88 , 222080.72 , 139429.38 , 150665.88 , 186637.11 ,
#        315968.44 , 207262.53 , 104908.35 , 285175.53 , 116361.85 ,
#        118724.055, 433383.7  ,  85027.22 , 389293.28 , 189875.08 ,
#        245436.83 , 142090.7  , 108339.92 , 104363.81 , 192886.84 ,
#        170493.36 , 152566.64 , 194025.17 , 107122.52 ,  98216.31 ,
#        174328.02 , 173475.97 , 236879.4  , 142510.81 , 175950.89 ,
#        187806.8  , 146812.6  , 210275.88 , 111038.69 , 115591.35 ,
#        237883.84 , 152994.12 , 192747.47 , 128992.61 , 233260.42 ,
#        157686.3  , 125777.7  , 124777.02 , 292413.16 , 128861.01 ,
#        366954.2  , 127963.24 , 102010.875, 153323.56 , 155190.3  ,
#        193383.1  , 152963.31 , 271239.25 , 161704.92 , 485930.72 ,
#        375105.88 , 216726.06 ,  97891.33 , 158887.05 , 142488.05 ,
#        119573.11 , 211988.56 , 180729.02 ,  83742.38 , 128773.83 ,
#         55806.477, 168056.55 , 188855.25 , 122706.836, 203450.75 ,
#        148518.47 ,  95323.65 , 259489.11 , 300649.25 , 120596.125,
#        123279.75 , 250336.31 , 152728.45 , 119703.62 , 140769.98 ,
#         94234.945, 168290.88 , 166419.05 , 191711.53 ,  87941.24 ,
#        182010.05 , 146718.42 , 114107.53 , 122736.35 , 176150.11 ,
#        205260.86 , 212214.73 , 252995.44 , 132529.86 , 185682.58 ,
#        337859.78 , 195085.9  ,  74669.164, 383141.62 , 170378.7  ,
#        102168.266, 145823.5  ,  75179.35 , 136282.61 , 108586.99 ,
#        228827.11 , 165447.16 , 148927.3  , 234606.89 , 164168.31 ,
#        213879.38 , 146356.19 , 400834.53 ,  94312.46 , 142589.72 ,
#        222089.36 , 189844.02 , 254229.72 , 127660.33 , 153490.25 ,
#        199619.56 , 227249.72 , 161212.38 ,  99755.6  ,  91232.03 ,
#        198281.14 , 135452.34 , 402307.3  , 183495.34 , 113284.234,
#        165985.34 , 173389.9  ,  99414.23 , 157471.06 , 195922.38 ,
#        164607.17 , 100338.3  , 173162.4  , 268138.7  , 230528.83 ,
#        134370.95 , 129832.77 , 318014.62 , 262726.88 , 277250.22 ,
#        216437.1  , 176542.73 ,  89240.03 , 190060.16 , 451435.12 ,
#        128356.52 , 362037.   , 159514.83 , 311401.1  , 139256.52 ,
#        128522.55 , 165066.6  , 245616.3  , 139376.5  , 146463.78 ,
#        154291.88 , 101820.76 ], dtype=float32)

# %%
rf_pred = regressor.predict(df_test)

# %%
## Correlation

corr = df_train.corr()

# %%
corr

# %%
# witnin the independent feature if your correlation is more than 0.9 then delete one of the feature

columns = np.full((corr.shape[0],),True,dtype=bool)
for i in range(corr.shape[0]):
    for j in range(i+1,corr.shape[0]):
        if corr.iloc[i,j] >= 0.9:
            if columns[j]:
                columns[j] = False

# %%
selected_columns = df_train.columns[columns]
data = df_train[selected_columns]

# %%
columns
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']
# [00:17:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END base_score=0.75, booster=gblinear, learning_rate=0.2, max_depth=15, min_child_weight=1, n_estimators=1500;, score=(train=-22379.957, test=-23483.321) total time=   0.5s
# [CV 1/5] END base_score=1, booster=gbtree, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=1100;, score=(train=-1854.955, test=-17012.202) total time=   1.4s
# [CV 5/5] END base_score=1, booster=gbtree, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=1100;, score=(train=-1690.279, test=-16152.797) total time=   1.4s
# [CV 4/5] END base_score=0.5, booster=gbtree, learning_rate=0.05, max_depth=15, min_child_weight=4, n_estimators=900;, score=(train=-5.956, test=-18615.776) total time=   5.1s
# [CV 3/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=2, min_child_weight=3, n_estimators=1500;, score=(train=-3226.720, test=-18531.598) total time=   1.4s
# [00:17:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END base_score=0.75, booster=gblinear, learning_rate=0.2, max_depth=15, min_child_weight=1, n_estimators=100;, score=(train=-23119.417, test=-23414.984) total time=   0.0s
# [00:17:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END base_score=0.75, booster=gblinear, learning_rate=0.2, max_depth=15, min_child_weight=1, n_estimators=100;, score=(train=-21823.657, test=-25707.594) total time=   0.0s
# [00:17:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END base_score=0.75, booster=gblinear, learning_rate=0.2, max_depth=15, min_child_weight=1, n_estimators=100;, score=(train=-22559.953, test=-25675.645) total time=   0.1s
# [00:17:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END base_score=0.75, booster=gblinear, learning_rate=0.2, max_depth=15, min_child_weight=1, n_estimators=100;, score=(train=-22969.939, test=-24181.327) total time=   0.1s
# [00:17:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END base_score=0.75, booster=gblinear, learning_rate=0.2, max_depth=15, min_child_weight=1, n_estimators=100;, score=(train=-23052.019, test=-20335.865) total time=   0.1s
# [CV 1/5] END base_score=1, booster=gbtree, learning_rate=0.2, max_depth=2, min_child_weight=3, n_estimators=1500;, score=(train=-2250.648, test=-17587.238) total time=   1.9s
# [CV 4/5] END base_score=1, booster=gbtree, learning_rate=0.2, max_depth=2, min_child_weight=3, n_estimators=1500;, score=(train=-2216.908, test=-18282.622) total time=   1.6s
# [CV 3/5] END base_score=1, booster=gbtree, learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=500;, score=(train=-27.327, test=-17633.064) total time=   1.9s
# [CV 3/5] END base_score=0.25, booster=gbtree, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=900;, score=(train=-6531.136, test=-16842.787) total time=   0.8s
# [CV 2/5] END base_score=0.25, booster=gbtree, learning_rate=0.1, max_depth=15, min_child_weight=3, n_estimators=900;, score=(train=-0.040, test=-20142.855) total time=   5.6s
# [00:18:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=5, min_child_weight=2, n_estimators=900;, score=(train=-20907.621, test=-25067.151) total time=   0.4s
# [00:18:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=5, min_child_weight=2, n_estimators=900;, score=(train=-22679.662, test=-19443.841) total time=   0.4s
# [CV 3/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=3, min_child_weight=2, n_estimators=1500;, score=(train=-409.271, test=-18684.081) total time=   2.1s
# [00:18:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END base_score=0.25, booster=gblinear, learning_rate=0.2, max_depth=10, min_child_weight=4, n_estimators=500;, score=(train=-22241.228, test=-23343.646) total time=   0.2s
# [00:18:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END base_score=0.25, booster=gblinear, learning_rate=0.2, max_depth=10, min_child_weight=4, n_estimators=500;, score=(train=-20866.626, test=-25016.326) total time=   0.2s
# [00:18:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END base_score=0.25, booster=gblinear, learning_rate=0.2, max_depth=10, min_child_weight=4, n_estimators=500;, score=(train=-20502.421, test=-23120.093) total time=   0.2s
# [00:18:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END base_score=0.25, booster=gblinear, learning_rate=0.2, max_depth=10, min_child_weight=4, n_estimators=500;, score=(train=-21792.355, test=-22956.869) total time=   0.2s
# [00:18:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END base_score=0.25, booster=gblinear, learning_rate=0.2, max_depth=10, min_child_weight=4, n_estimators=500;, score=(train=-22646.922, test=-19484.009) total time=   0.2s
# [00:18:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END base_score=0.5, booster=gblinear, learning_rate=0.05, max_depth=3, min_child_weight=4, n_estimators=500;, score=(train=-22850.391, test=-23614.609) total time=   0.2s
# [00:18:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END base_score=0.5, booster=gblinear, learning_rate=0.05, max_depth=3, min_child_weight=4, n_estimators=500;, score=(train=-21562.315, test=-25397.961) total time=   0.2s
# [00:18:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END base_score=0.5, booster=gblinear, learning_rate=0.05, max_depth=3, min_child_weight=4, n_estimators=500;, score=(train=-21436.322, test=-24482.591) total time=   0.2s
# [00:18:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END base_score=0.5, booster=gblinear, learning_rate=0.05, max_depth=3, min_child_weight=4, n_estimators=500;, score=(train=-22514.311, test=-23356.605) total time=   0.2s
# [00:18:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END base_score=0.5, booster=gblinear, learning_rate=0.05, max_depth=3, min_child_weight=4, n_estimators=500;, score=(train=-23169.670, test=-20535.513) total time=   0.2s
# [CV 4/5] END base_score=1, booster=gbtree, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=900;, score=(train=-0.067, test=-20268.352) total time=   5.7s
# [CV 5/5] END base_score=1, booster=gbtree, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=900;, score=(train=-0.075, test=-16620.842) total time=   5.4s
# [CV 4/5] END base_score=0.5, booster=gbtree, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=500;, score=(train=-0.041, test=-20848.121) total time=   3.1s
# [00:18:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=5, min_child_weight=4, n_estimators=900;, score=(train=-20468.808, test=-23101.921) total time=   0.3s
# [00:18:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END base_score=0.75, booster=gblinear, learning_rate=0.05, max_depth=2, min_child_weight=2, n_estimators=100;, score=(train=-25314.653, test=-25347.104) total time=   0.0s
# [00:18:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END base_score=0.75, booster=gblinear, learning_rate=0.05, max_depth=2, min_child_weight=2, n_estimators=100;, score=(train=-24832.093, test=-28320.288) total time=   0.0s
# [00:18:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END base_score=1, booster=gblinear, learning_rate=0.05, max_depth=15, min_child_weight=4, n_estimators=100;, score=(train=-25486.583, test=-25569.351) total time=   0.0s
# [00:18:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END base_score=1, booster=gblinear, learning_rate=0.05, max_depth=15, min_child_weight=4, n_estimators=100;, score=(train=-24915.109, test=-25810.743) total time=   0.0s
# [00:18:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END base_score=1, booster=gblinear, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=900;, score=(train=-22363.842, test=-23301.563) total time=   0.3s
# [00:18:29] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END base_score=1, booster=gblinear, learning_rate=0.05, max_depth=5, min_child_weight=3, n_estimators=900;, score=(train=-22659.614, test=-19884.897) total time=   0.3s
# [CV 4/5] END base_score=1, booster=gbtree, learning_rate=0.15, max_depth=5, min_child_weight=2, n_estimators=100;, score=(train=-4325.654, test=-18031.785) total time=   0.2s
# [CV 2/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=15, min_child_weight=2, n_estimators=1500;, score=(train=-0.031, test=-20619.481) total time=  10.2s
# [00:18:39] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=15, min_child_weight=2, n_estimators=500;, score=(train=-22519.678, test=-23364.972) total time=   0.4s
# [00:18:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END base_score=0.75, booster=gblinear, learning_rate=0.1, max_depth=15, min_child_weight=2, n_estimators=100;, score=(train=-23723.241, test=-23892.479) total time=   0.1s
# [00:18:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END base_score=0.75, booster=gblinear, learning_rate=0.1, max_depth=15, min_child_weight=2, n_estimators=100;, score=(train=-23426.626, test=-27004.898) total time=   0.1s
# [00:18:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END base_score=0.75, booster=gblinear, learning_rate=0.1, max_depth=15, min_child_weight=2, n_estimators=100;, score=(train=-23701.441, test=-27110.322) total time=   0.1s
# [00:18:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END base_score=0.75, booster=gblinear, learning_rate=0.1, max_depth=15, min_child_weight=2, n_estimators=100;, score=(train=-24249.083, test=-25282.354) total time=   0.1s
# [00:18:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=-22237.263, test=-23269.712) total time=   0.3s
# [00:18:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=-20506.117, test=-23100.520) total time=   0.3s
# [00:18:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=3, min_child_weight=1, n_estimators=500;, score=(train=-22545.187, test=-19479.996) total time=   0.2s
# [CV 3/5] END base_score=0.75, booster=gbtree, learning_rate=0.15, max_depth=2, min_child_weight=3, n_estimators=500;, score=(train=-7263.780, test=-18109.956) total time=   0.6s
# [00:18:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=15, min_child_weight=4, n_estimators=100;, score=(train=-25207.165, test=-25219.600) total time=   0.0s
# [00:18:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=15, min_child_weight=4, n_estimators=100;, score=(train=-24446.117, test=-27652.093) total time=   0.0s
# [00:18:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=15, min_child_weight=4, n_estimators=100;, score=(train=-24660.376, test=-28173.615) total time=   0.0s
# [00:18:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=15, min_child_weight=4, n_estimators=100;, score=(train=-24937.276, test=-25840.965) total time=   0.0s
# [00:18:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END base_score=0.25, booster=gblinear, learning_rate=0.05, max_depth=15, min_child_weight=4, n_estimators=100;, score=(train=-25539.582, test=-23077.621) total time=   0.0s
# [CV 1/5] END base_score=0.5, booster=gbtree, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=1500;, score=(train=-0.038, test=-16570.705) total time=  11.0s
# [CV 5/5] END base_score=0.5, booster=gbtree, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=1500;, score=(train=-0.025, test=-17263.603) total time=  11.0s
# [CV 3/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=5, min_child_weight=4, n_estimators=500;, score=(train=-226.714, test=-17881.588) total time=   1.6s
# [CV 2/5] END base_score=0.5, booster=gbtree, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=100;, score=(train=-13372.095, test=-21959.334) total time=   0.2s
# [CV 5/5] END base_score=0.5, booster=gbtree, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=100;, score=(train=-13687.436, test=-16839.844) total time=   0.1s
# [00:19:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END base_score=1, booster=gblinear, learning_rate=0.15, max_depth=3, min_child_weight=2, n_estimators=900;, score=(train=-20476.670, test=-23109.955) total time=   0.5s
# [00:19:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END base_score=0.25, booster=gblinear, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=1100;, score=(train=-22223.267, test=-23348.035) total time=   0.5s
# [00:19:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END base_score=0.25, booster=gblinear, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=1100;, score=(train=-22628.476, test=-19469.836) total time=   0.5s
# [00:19:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END base_score=0.5, booster=gblinear, learning_rate=0.05, max_depth=15, min_child_weight=2, n_estimators=1500;, score=(train=-21791.273, test=-22803.965) total time=   0.7s
# [CV 3/5] END base_score=0.75, booster=gbtree, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=1100;, score=(train=-26.079, test=-17605.502) total time=   3.0s
# [00:19:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END base_score=1, booster=gblinear, learning_rate=0.1, max_depth=10, min_child_weight=2, n_estimators=1100;, score=(train=-20871.034, test=-25013.576) total time=   0.6s
# [00:19:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END base_score=1, booster=gblinear, learning_rate=0.1, max_depth=10, min_child_weight=2, n_estimators=1100;, score=(train=-22620.263, test=-19451.350) total time=   0.4s
# [00:19:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END base_score=0.25, booster=gblinear, learning_rate=0.15, max_depth=5, min_child_weight=1, n_estimators=900;, score=(train=-20493.474, test=-23127.180) total time=   0.4s
# [00:19:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END base_score=0.75, booster=gblinear, learning_rate=0.2, max_depth=2, min_child_weight=3, n_estimators=1500;, score=(train=-22365.574, test=-23469.439) total time=   1.0s
# [00:19:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END base_score=0.75, booster=gblinear, learning_rate=0.2, max_depth=2, min_child_weight=3, n_estimators=1500;, score=(train=-21826.266, test=-23176.731) total time=   0.8s
# [00:19:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END base_score=0.5, booster=gblinear, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=1500;, score=(train=-20473.283, test=-23111.099) total time=   0.7s
# [00:19:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END base_score=0.75, booster=gblinear, learning_rate=0.1, max_depth=15, min_child_weight=2, n_estimators=1100;, score=(train=-20873.089, test=-25013.652) total time=   0.5s
# [00:17:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END base_score=0.75, booster=gblinear, learning_rate=0.2, max_depth=15, min_child_weight=1, n_estimators=1500;, score=(train=-20984.069, test=-25157.732) total time=   0.5s
# [CV 2/5] END base_score=1, booster=gbtree, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=1100;, score=(train=-1923.590, test=-21101.334) total time=   1.3s
# [00:17:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END base_score=0.75, booster=gblinear, learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=500;, score=(train=-22322.909, test=-23269.438) total time=   0.2s
# [00:17:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END base_score=0.75, booster=gblinear, learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=500;, score=(train=-20617.346, test=-23350.935) total time=   0.2s
# [00:17:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END base_score=0.75, booster=gblinear, learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=500;, score=(train=-22578.184, test=-19731.960) total time=   0.2s
# [CV 3/5] END base_score=0.5, booster=gbtree, learning_rate=0.05, max_depth=15, min_child_weight=4, n_estimators=900;, score=(train=-13.746, test=-18121.451) total time=   5.0s
# [CV 1/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=2, min_child_weight=3, n_estimators=1500;, score=(train=-3210.941, test=-17312.176) total time=   1.5s
# [CV 4/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=2, min_child_weight=3, n_estimators=1500;, score=(train=-3097.851, test=-18319.305) total time=   1.4s
# [CV 2/5] END base_score=1, booster=gbtree, learning_rate=0.2, max_depth=2, min_child_weight=3, n_estimators=1500;, score=(train=-2086.481, test=-22895.328) total time=   1.9s
# [CV 1/5] END base_score=1, booster=gbtree, learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=500;, score=(train=-18.916, test=-18267.478) total time=   1.9s
# [CV 5/5] END base_score=1, booster=gbtree, learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=500;, score=(train=-21.636, test=-16624.563) total time=   1.9s
# [CV 5/5] END base_score=0.25, booster=gbtree, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=900;, score=(train=-6541.252, test=-16085.913) total time=   0.9s
# [CV 4/5] END base_score=0.25, booster=gbtree, learning_rate=0.1, max_depth=15, min_child_weight=3, n_estimators=900;, score=(train=-0.059, test=-19639.444) total time=   5.3s
# [00:18:09] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=5, min_child_weight=2, n_estimators=900;, score=(train=-21791.288, test=-23013.662) total time=   0.3s
# [CV 2/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=3, min_child_weight=2, n_estimators=1500;, score=(train=-371.025, test=-21530.354) total time=   2.1s
# [CV 5/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=3, min_child_weight=2, n_estimators=1500;, score=(train=-386.615, test=-16486.846) total time=   2.0s
# [CV 3/5] END base_score=1, booster=gbtree, learning_rate=0.1, max_depth=15, min_child_weight=1, n_estimators=900;, score=(train=-0.067, test=-18166.104) total time=   5.8s
# [CV 2/5] END base_score=0.25, booster=gbtree, learning_rate=0.05, max_depth=2, min_child_weight=4, n_estimators=900;, score=(train=-9113.373, test=-21502.345) total time=   0.9s
# [CV 1/5] END base_score=0.5, booster=gbtree, learning_rate=0.2, max_depth=3, min_child_weight=2, n_estimators=900;, score=(train=-649.546, test=-17893.586) total time=   1.3s
# [CV 4/5] END base_score=0.5, booster=gbtree, learning_rate=0.2, max_depth=3, min_child_weight=2, n_estimators=900;, score=(train=-640.103, test=-18834.696) total time=   1.3s
# [CV 3/5] END base_score=0.25, booster=gbtree, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=100;, score=(train=-1794.085, test=-17955.512) total time=   0.4s
# [CV 4/5] END base_score=0.25, booster=gbtree, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=100;, score=(train=-1401.875, test=-19760.743) total time=   0.4s
# [00:18:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END base_score=0.75, booster=gblinear, learning_rate=0.15, max_depth=5, min_child_weight=2, n_estimators=900;, score=(train=-20909.033, test=-25066.570) total time=   0.3s
# [00:18:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END base_score=0.75, booster=gblinear, learning_rate=0.15, max_depth=5, min_child_weight=2, n_estimators=900;, score=(train=-22680.529, test=-19443.632) total time=   0.3s
# [CV 3/5] END base_score=0.5, booster=gbtree, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=500;, score=(train=-0.051, test=-18530.631) total time=   3.1s
# [00:18:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END base_score=0.25, booster=gblinear, learning_rate=0.15, max_depth=2, min_child_weight=2, n_estimators=100;, score=(train=-23608.995, test=-24001.935) total time=   0.0s
# [00:18:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END base_score=0.25, booster=gblinear, learning_rate=0.15, max_depth=2, min_child_weight=2, n_estimators=100;, score=(train=-22684.468, test=-26022.920) total time=   0.0s
# [00:18:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END base_score=0.25, booster=gblinear, learning_rate=0.15, max_depth=2, min_child_weight=2, n_estimators=100;, score=(train=-23913.489, test=-21309.119) total time=   0.0s
# [00:18:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=5, min_child_weight=4, n_estimators=900;, score=(train=-20895.891, test=-25054.555) total time=   0.3s
# [00:18:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=5, min_child_weight=4, n_estimators=900;, score=(train=-22693.330, test=-19467.861) total time=   0.3s
# [00:18:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END base_score=0.75, booster=gblinear, learning_rate=0.05, max_depth=2, min_child_weight=2, n_estimators=100;, score=(train=-25047.141, test=-26007.018) total time=   0.0s
# ...
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END base_score=1, booster=gblinear, learning_rate=0.2, max_depth=2, min_child_weight=3, n_estimators=1500;, score=(train=-21820.162, test=-23166.851) total time=   0.9s
# [00:18:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END base_score=0.75, booster=gblinear, learning_rate=0.05, max_depth=10, min_child_weight=2, n_estimators=1500;, score=(train=-22220.686, test=-23284.309) total time=   1.0s
# [00:18:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END base_score=0.75, booster=gblinear, learning_rate=0.05, max_depth=10, min_child_weight=2, n_estimators=1500;, score=(train=-20469.511, test=-23122.112) total time=   0.6s
# [00:18:59] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END base_score=0.75, booster=gblinear, learning_rate=0.05, max_depth=10, min_child_weight=2, n_estimators=1500;, score=(train=-22549.201, test=-19526.547) total time=   0.6s
# [CV 2/5] END base_score=0.25, booster=gbtree, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=900;, score=(train=-615.258, test=-22186.159) total time=   1.4s
# [CV 4/5] END base_score=0.25, booster=gbtree, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=900;, score=(train=-680.020, test=-17891.034) total time=   1.4s
# [00:19:02] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END base_score=0.75, booster=gblinear, learning_rate=0.15, max_depth=2, min_child_weight=1, n_estimators=1100;, score=(train=-20924.536, test=-25088.880) total time=   0.5s
# [00:19:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END base_score=0.75, booster=gblinear, learning_rate=0.15, max_depth=2, min_child_weight=1, n_estimators=1100;, score=(train=-21790.518, test=-23044.152) total time=   0.6s
# [00:19:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=500;, score=(train=-20836.015, test=-24970.161) total time=   0.3s
# [00:19:03] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END base_score=0.5, booster=gblinear, learning_rate=0.15, max_depth=15, min_child_weight=3, n_estimators=500;, score=(train=-21750.934, test=-22855.479) total time=   0.3s
# [CV 2/5] END base_score=0.25, booster=gbtree, learning_rate=0.15, max_depth=5, min_child_weight=4, n_estimators=500;, score=(train=-265.399, test=-21185.841) total time=   1.6s
# [CV 1/5] END base_score=0.5, booster=gbtree, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=100;, score=(train=-14039.807, test=-17113.317) total time=   0.1s
# [CV 4/5] END base_score=0.5, booster=gbtree, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=100;, score=(train=-13796.956, test=-18546.862) total time=   0.2s
# [00:19:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END base_score=1, booster=gblinear, learning_rate=0.15, max_depth=3, min_child_weight=2, n_estimators=900;, score=(train=-20902.991, test=-25062.079) total time=   0.4s
# [00:19:06] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END base_score=1, booster=gblinear, learning_rate=0.15, max_depth=3, min_child_weight=2, n_estimators=900;, score=(train=-22681.821, test=-19443.510) total time=   0.4s
# [00:19:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END base_score=0.25, booster=gblinear, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=1100;, score=(train=-21775.348, test=-22927.708) total time=   0.4s
# [00:19:07] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END base_score=0.5, booster=gblinear, learning_rate=0.05, max_depth=15, min_child_weight=2, n_estimators=1500;, score=(train=-20481.979, test=-23122.731) total time=   0.6s
# [CV 2/5] END base_score=0.75, booster=gbtree, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=1100;, score=(train=-32.363, test=-20434.229) total time=   3.0s
# [00:19:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END base_score=1, booster=gblinear, learning_rate=0.1, max_depth=10, min_child_weight=2, n_estimators=1100;, score=(train=-22218.282, test=-23347.841) total time=   0.6s
# [00:19:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5] END base_score=1, booster=gblinear, learning_rate=0.1, max_depth=10, min_child_weight=2, n_estimators=1100;, score=(train=-20463.507, test=-23095.619) total time=   0.4s
# [00:19:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END base_score=0.25, booster=gblinear, learning_rate=0.15, max_depth=5, min_child_weight=1, n_estimators=900;, score=(train=-22265.055, test=-23396.105) total time=   0.4s
# [00:19:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END base_score=0.25, booster=gblinear, learning_rate=0.15, max_depth=5, min_child_weight=1, n_estimators=900;, score=(train=-21786.965, test=-23010.507) total time=   0.5s
# [00:19:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END base_score=0.75, booster=gblinear, learning_rate=0.2, max_depth=2, min_child_weight=3, n_estimators=1500;, score=(train=-20986.137, test=-25161.660) total time=   0.9s
# [00:19:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END base_score=0.5, booster=gblinear, learning_rate=0.2, max_depth=15, min_child_weight=3, n_estimators=100;, score=(train=-23452.801, test=-24105.652) total time=   0.1s
# [00:19:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5] END base_score=0.5, booster=gblinear, learning_rate=0.2, max_depth=15, min_child_weight=3, n_estimators=100;, score=(train=-21811.626, test=-25590.488) total time=   0.1s
# [00:19:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5] END base_score=0.5, booster=gblinear, learning_rate=0.2, max_depth=15, min_child_weight=3, n_estimators=100;, score=(train=-22797.598, test=-24058.812) total time=   0.1s
# [00:19:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END base_score=0.5, booster=gblinear, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=1500;, score=(train=-22279.576, test=-23416.913) total time=   0.7s
# [00:19:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END base_score=0.5, booster=gblinear, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=1500;, score=(train=-22697.057, test=-19458.336) total time=   0.7s
# [00:19:15] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "max_depth", "min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5] END base_score=0.75, booster=gblinear, learning_rate=0.1, max_depth=15, min_child_weight=2, n_estimators=1100;, score=(train=-22625.059, test=-19466.649) total time=   0.4s

# %% [markdown]
# ### Above are the important features which affect the price.
